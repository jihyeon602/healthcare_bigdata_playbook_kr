# %%
# 부재정보를 뺀 누적바 그래프를 그려보자
df_not_absence = pd.read_csv('ch10/stacked_not_absence.csv', encoding="CP949")

from matplotlib import font_manager, rc

plt.rc('font', family='Malgun Gothic')


plt.rcParams['figure.figsize'] = [10, 8]
ax = df_not_absence.plot.bar(stacked=True)

handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='best')  # reverse both handles and labels

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# 부재 정보를 포함해서 살펴보자
df_ratio = pd.read_csv('stacked_ratio.csv', encoding="CP949")
df_ratio.head()
# Out:
#   deviceId    부재  미활동    활동   주의  낙상
# 0      #01  2793  843   664   20   0
# 1      #02  3906  175   236    3   0
# 2      #03  2827  275  1042  174   2
# 3      #04  1046  613  2647   14   0
# 4      #05  1046  650  2606   17   1

# %%
plt.rc('font', family='Malgun Gothic')

plt.rcParams['figure.figsize'] = [10, 8]
ax = df_ratio.plot.bar(stacked=True)


handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='best')  # reverse both handles and labels

# %%
#
# 특히 센서#1, 센서#2에서는 노약자의 움직임이 거의 없는 점이 확인된다.
# 해당 병실은 1인실로써 노약자가 재실하는 않는 경우가 많은 것으로 확인된다.
# 위 그래프와 같이, '부재','미활동', '활동' 집계해 봄으로써, 노약자의 활동성이 원격으로 충분히 모니터링될 수 있다.
# '미활동','활동'은 '재실'로 간주된다.
# 또한, 활동량이 적은 노약자와 의료데이터를 참조해 봄으로써, 해당 노약자의 건강상태를 재확인할 수 있을 것이다.

# 그렇다면, '주의' 및 '낙상'이 많은 감지된 센서 데이터와 '주의' 및 '낙상'이 적게 감지된 센서 데이터를 비교해 보자.
