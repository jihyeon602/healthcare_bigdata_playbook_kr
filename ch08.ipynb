# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]

act = pd.read_csv('OTg6QzA_activities2.csv')
act.shape #데이터 구조, 행열 크기 알아보기
# Out:
# (66281, 3)

# %%
act.head(5)
# Out:
#                  timestamp   X   Y
# 0  2022-01-01 00:01:40.363  33  76
# 1  2022-01-01 00:01:42.961  34  87
# 2  2022-01-01 00:01:45.562  25  89
# 3  2022-01-01 00:01:48.163  11  70
# 4  2022-01-01 00:02:08.864  33  72

# %%
X = act.X.to_numpy()
Y = act.Y.to_numpy()

# %%
# Out:
# array([ 33,  34,  25, ..., -93, -93, -91], dtype=int64)

# %%
x1 = X[:16570]

# %%
x2 = X[16570:16570*2]
x3 = X[16570*2:16570*3]
x4 = X[16570*3:]

# %%
x4
# Out:
# array([-89, -90, -88, ..., -93, -93, -91], dtype=int64)

# %%
Y
# Out:
# array([ 76,  87,  89, ..., 138, 131, 129], dtype=int64)

# %%
plt.scatter(X, Y)
plt.show()

# %%
X
# Out:
# array([ 33,  34,  25, ..., -93, -93, -91], dtype=int64)

# %%
XY = act.X.to_numpy(),act.Y.to_numpy()
XY
# Out:
# (array([ 33,  34,  25, ..., -93, -93, -91], dtype=int64),
#  array([ 76,  87,  89, ..., 138, 131, 129], dtype=int64))

# %%
plt.matshow(XY)

plt.show()

# %%
arr = np.random.standard_normal((30, 40))

plt.matshow(arr)
plt.colorbar()
plt.show()

# %%
plt.hist2d(X, Y, bins=20, cmap='Oranges')
cb = plt.colorbar()
cb.set_label('frequency of appearance, bins=20')

# %%
plt.hexbin(X, Y, gridsize=20, cmap='Oranges')
cb = plt.colorbar()
cb.set_label('frequency of appearance, gridsize=20')

# %%
x1 = X[:16570]
x2 = X[16570:16570*2]
x3 = X[16570*2:16570*3]
x4 = X[16570*3:]

y1 = Y[:16570]
y2 = Y[16570:16570*2]
y3 = Y[16570*2:16570*3]
y4 = Y[16570*3:]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
image1 = ax1.hist2d(x1, y1, bins=20, cmap='Oranges')
ax1.set_title('First')


ax2 = fig.add_subplot(2,2,2)
ax2.hist2d(x2, y2, bins=20, cmap='Oranges')
ax2.set_title('Second')

ax3 = fig.add_subplot(2,2,3)
ax3.hist2d(x3, y3, bins=20, cmap='Oranges')
ax3.set_title('Thrid')

ax4 = fig.add_subplot(2,2,4)
ax4.hist2d(x4, y4, bins=20, cmap='Oranges')
ax4.set_title('Fourth')


plt.show()

# %%
X_dash = X[16570:]
Y_dash = Y[16570:]
plt.hist2d(X_dash, Y_dash, bins=20, cmap='Oranges')
cb = plt.colorbar()
cb.set_label('frequency of appearance, bins=20')

# %%
X_dash[:50]
# Out:
# array([  0,   0,   0,   0,  83,  38,  65,  25,  25,  35,  32,  33,  35,
#         25,  21,  16,  15,   9,  17,  37, 150,  94, 110,  92, 140, 129,
#         28,  54,  53, -14, -21,  65, 123, -84, -70, -63, -77, -46, -74,
#        -57, -41,   3, 121, 105,  78, 107,  99, 109,  83, 116], dtype=int64)
